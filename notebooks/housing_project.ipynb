# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score

#makes your graphs appear inside the notebook
# %matplotlib inline
print("✅All libraries imported successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 6
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#       4 import matplotlib.ticker as ticker
#       5 import seaborn as sns
# ----> 6 from sklearn.linear_model import LinearRegression
#       7 from sklearn.model_selection import train_test_split
#       8 from sklearn.metrics import mean_absolute_error, r2_score
#       9
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
df1 = pd.read_csv("../data/mexico-real-estate-1.csv")
df2 = pd.read_csv("../data/mexico-real-estate-2.csv")
df3 = pd.read_csv("../data/mexico-real-estate-3.csv")

print("df1 shape:", df1.shape)
print("df2 shape:", df2.shape)
print("df3 shape:", df3.shape)
# Out:
# df1 shape: (700, 6)
# df2 shape: (700, 6)
# df3 shape: (700, 5)

# %%
df3.head(10)
# Out:
#   property_type                            place_with_parent_names  \
# 0     apartment  |México|Distrito Federal|Gustavo A. Madero|Acu...
# 1         house           |México|Estado de México|Toluca|Metepec|
# 2         house  |México|Estado de México|Toluca|Toluca de Lerd...
# 3         house        |México|Morelos|Temixco|Burgos Bugambilias|
# 4     apartment  |México|Veracruz de Ignacio de la Llave|Veracruz|
# 5         house                       |México|Jalisco|Guadalajara|
# 6         house                          |México|Sinaloa|Mazatlán|
# 7     apartment                        |México|Tamaulipas|Tampico|
# 8     apartment           |México|Distrito Federal|Miguel Hidalgo|
# 9         house                            |México|Yucatán|Mérida|
#
#                   lat-lon  area_m2  price_usd
# 0     19.52589,-99.151703       71   48550.59
# 1  19.2640539,-99.5727534      233  168636.73
# 2    19.268629,-99.671722      300   86932.69
# 3                     NaN      275  263432.41
# 4    19.511938,-96.871956       84   68508.67
# 5   20.689157,-103.366728      175  102763.00
# 6                     NaN      146  152421.99
# 7                     NaN      165  105397.95
# 8                     NaN       80  310923.97
# 9  21.0441317,-89.6216334      223  126477.54

# %%
print("=== FILE 1 ISSUES ===")
print("Columns:", df1.columns.tolist())
print("Data types:\n", df1.dtypes)
print("Missing values:\n", df1.isnull().sum())

print("\n=== FILE 2 ISSUES ===")
print("Columns:", df2.columns.tolist())
print("Data types:\n", df2.dtypes)
print("Missing values:\n", df2.isnull().sum())

print("\n=== FILE 3 ISSUES ===")
print("Columns:", df3.columns.tolist())
print("Data types:\n", df3.dtypes)
print("Missing values:\n", df3.isnull().sum())
# Out:
# === FILE 1 ISSUES ===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 print("=== FILE 1 ISSUES ===")
# ----> 2 print("Columns:", df1.columns.tolist())
#       3 print("Data types:\n", df1.dtypes)
#       4 print("Missing values:\n", df1.isnull().sum())
#       5
#
# NameError: name 'df1' is not defined
